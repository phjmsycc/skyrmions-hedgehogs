# %% [markdown]
# # Skyrmions

# %%
include("spin-textures-skyrmions.jl")
# Out:
# makeDirectories (generic function with 1 method)

# %%
# makeDirectories()

# %%
Nₛ = 16
m = 0.0
# phi = [sqrt(2)/3*pi, sqrt(2)/3*3pi, sqrt(2)/3*5pi]
phi = [pi, pi, pi]
p = (; Nₛ, m, phi)
# Out:
# (Nₛ = 16, m = 0.0, phi = [π, π, π])

# %%
fig = writeSpinTexture(p)

# %%
# figName = "spinTextures-skyrmion_test9"
# save(figName * ".pdf", fig)
# save(figName * ".png", fig)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
include("spin-textures-skyrmions.jl")
# Out:
# makeDirectories (generic function with 1 method)

# %%
Nₛ = 16
m = 0.0
# theta0 = 0.0 # pi/2
theta0 = pi/2
# phi = [sqrt(2)/3*pi, sqrt(2)/3*3pi, sqrt(2)/3*5pi]
phi = [pi, pi, pi]
p = (; Nₛ, m, phi, theta0)
# Out:
# (Nₛ = 16, m = 0.0, phi = [π, π, π], theta0 = 1.5707963267948966)

# %%
fig = writeSpinTexturePolar(p)

# %%
figName = "spinTextures-skyrmion_20230818_10"
# save(figName * ".pdf", fig)
save(figName * ".png", fig; resolution = (5000, 5000))

# %% [markdown]
# # Hedgehogs

# %%
include("spin-textures-hedgehogs.jl")
# Out:
# makeDirectories (generic function with 1 method)

# %%
Nₛ = 16
m = 0.0
theta0 = 0.0 # pi/2
# phi = [sqrt(2)/3*pi, sqrt(2)/3*3pi, sqrt(2)/3*5pi]
# phi = [pi, pi, pi]
phi = [0, 0, 0]
p = (; Nₛ, m, phi, theta0)
# Out:
# (Nₛ = 16, m = 0.0, phi = [0, 0, 0], theta0 = 0.0)

# %%
fig = writeSpinTexturePolar(p)

# %%
figName = "spinTextures-hedgehog_20230818_5"
# save(figName * ".pdf", fig)
save(figName * ".png", fig; resolution = (5000, 5000))
